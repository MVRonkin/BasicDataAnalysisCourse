# %% [markdown]
# # Базовое решение
# ## Импорт данных

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error 

import numpy as np

# %%
df=pd.read_csv('cars_train.csv')
df
# Out:
#       Price           Make    Model  Year      Style    Fuel     Engine  \
# 0     16621      CHEVROLET  Equinox  2011       Jeep  Petrol          3
# 1      8467          HONDA      FIT  2006  Hatchback  Petrol        1.3
# 2     11726          HONDA      FIT  2014  Hatchback  Petrol        1.3
# 3     26657          LEXUS   RX 350  2007       Jeep  Petrol        NaN
# 4      8781           FORD  Transit  1999   Microbus     CNG          4
# ...     ...            ...      ...   ...        ...     ...        ...
# 9614   5802  MERCEDES-BENZ    E 350  2013      Sedan  Diesel        3.5
# 9615   8467  MERCEDES-BENZ  CLK 200  1999      Coupe     CNG  2.0 Turbo
# 9616  15681        HYUNDAI   Sonata  2011      Sedan  Petrol        2.4
# 9617  26108        HYUNDAI   Tucson  2010       Jeep  Diesel          2
# 9618    470        HYUNDAI   Sonata  2012      Sedan  Hybrid        2.4
#
#        Distance  Cylinders Transmission  Drive             Wheel   Color    ID
# 0     192000 km        6.0    Tiptronic    4x4        Left wheel   Black     0
# 1     200000 km        4.0     Variator  Front  Right-hand drive   Black     1
# 2      91901 km        4.0    Automatic  Front        Left wheel  Silver     2
# 3     128500 km        6.0    Automatic    4x4        Left wheel  Silver     3
# 4          0 km        8.0       Manual   Rear        Left wheel    Blue     4
# ...         ...        ...          ...    ...               ...     ...   ...
# 9614  107800 km        6.0    Automatic   Rear        Left wheel    Grey  9614
# 9615  300000 km        4.0       Manual   Rear        Left wheel  Silver  9615
# 9616  161600 km        4.0    Tiptronic  Front        Left wheel     Red  9616
# 9617  116365 km        4.0    Automatic  Front        Left wheel    Grey  9617
# 9618  186923 km        4.0    Automatic  Front        Left wheel   White  9618
#
# [9619 rows x 14 columns]

# %% [markdown]
# ## Базовая очистка данных

# %%
def clear_df(df):
    df['Engine'] = df['Engine'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)
    df['Distance'] = df['Distance'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)
    df['Wheel'] = df['Wheel'].map({'Left wheel':0,'Right-hand drive':1})
    df['Transmission'] = (df['Transmission'] == 'Manual').astype(int)
    df['Drive'] = (df['Drive'] == '4x4').astype(int)
    return df

# %% [markdown]
# ID тоже пока не нужно

# %%
df = clear_df(df).drop(columns=['ID'])

# %%
df.describe()
# Out:
#               Price         Year       Engine      Distance    Cylinders  \
# count  9.619000e+03  9619.000000  9523.000000  9.619000e+03  9523.000000
# mean   1.966454e+04  2010.955921     2.308548  1.873337e+06     4.566418
# std    2.686682e+05     5.666966     0.872758  5.588837e+07     1.180370
# min    1.000000e+00  1939.000000     0.000000  0.000000e+00     1.000000
# 25%    5.331000e+03  2009.000000     1.800000  6.940750e+04     4.000000
# 50%    1.300000e+04  2012.000000     2.000000  1.250000e+05     4.000000
# 75%    2.206300e+04  2015.000000     2.500000  1.874170e+05     4.000000
# max    2.630750e+07  2020.000000    20.000000  2.147484e+09    16.000000
#
#        Transmission        Drive        Wheel
# count   9619.000000  9619.000000  9619.000000
# mean       0.095020     0.207194     0.077243
# std        0.293258     0.405317     0.266990
# min        0.000000     0.000000     0.000000
# 25%        0.000000     0.000000     0.000000
# 50%        0.000000     0.000000     0.000000
# 75%        0.000000     0.000000     0.000000
# max        1.000000     1.000000     1.000000

# %% [markdown]
# ## EDA должно быть тут

# %% [markdown]
# ...

# %% [markdown]
# ## Выбор колонок для обучения модели

# %% [markdown]
# X - входные данные, y - целевая колонка

# %%
numeric_df = df.select_dtypes(include='number')

numeric_df = numeric_df.dropna()

X = numeric_df.drop('Price', axis=1)
y = numeric_df['Price']

X.head(3)
# Out:
#    Year  Engine  Distance  Cylinders  Transmission  Drive  Wheel
# 0  2011     3.0  192000.0        6.0             0      1      0
# 1  2006     1.3  200000.0        4.0             0      0      1
# 2  2014     1.3   91901.0        4.0             0      0      0

# %% [markdown]
# ## Обучение модели

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

model = RandomForestRegressor(n_estimators=10, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=42)

# %%
# Предсказание
y_pred = model.predict(X_train)


MAE = mean_absolute_error(y_train, y_pred)
MAPE = mean_absolute_percentage_error(y_train, y_pred)  

print("MAE:", MAE)
print("MAPE, %:", MAPE )
# Out:
# MAE: 3381.558765629821
# MAPE, %: 4.09844113134101

# %% [markdown]
# ## Предсказание на валидационной выборке для оценки точности

# %%
# Предсказание
y_pred = model.predict(X_test)


MAE = mean_absolute_error(y_test, y_pred)
MAPE = mean_absolute_percentage_error(y_test, y_pred)  

print("MAE:", MAE)
print("MAPE, %:", MAPE )
# Out:
# MAE: 35359.18003770443
# MAPE, %: 15.137822580840846

# %% [markdown]
# ## Тест

# %% [markdown]
# ### Сформируем результат для тестового набора

# %%
df_test=pd.read_csv('cars_test.csv')

df_test = clear_df(df_test) 

df_test = df_test.dropna().drop_duplicates()

X_test = df_test[X.columns]

y_pred = model.predict(X_test)

df_submit = df_test[['ID']].copy()

df_submit['Predict'] = y_pred

df_submit.shape
# Out:
# (9618, 2)

# %% [markdown]
# ### Сохраним `Submit.csv` (для отправки)

# %%
df_submit.to_csv('submit.csv', index = False)
df_submit.head(3)
# Out:
#    ID       Predict
# 0   0  12890.233333
# 1   1   4864.300000
# 2   2   4602.100000

# %% [markdown]
# # Как будет проходить проверка (Для справки)

# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error

# %%
df_submit=pd.read_csv('submit.csv')
df_test=pd.read_csv('cars_test_full.csv')


df_merged = pd.merge(df_submit, df_test, on='ID', how='left').drop_duplicates()

y_true = df_merged['Price']
y_pred = df_merged['Predict']

MAE = mean_absolute_error(y_true, y_pred)
MAPE = mean_absolute_percentage_error(y_true, y_pred)  

print("MAE:", MAE)
print("MAPE, %:", MAPE )
# Out:
# MAE: 8479.287384826877
# MAPE, %: 17.05526244051365
